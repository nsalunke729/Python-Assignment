# %% [markdown]
# # Welcome to Assignment1

# %%
#List with functions
l=[4,5,8];
print(l);
l.append(9);
print(l);
a=l.count(4);
print("count of 4 in List l is : ", a);
l.reverse();
print("Reverse of List l is : ", l);
print("Popped Element is : ", l.pop());
k=[1,2,3];
l.extend(k);
print(l);
l.sort();
print("list in sorted order : ",l);
k.clear();
print("list k is cleared : ", k);
k=l.copy();
print("List L is copied in K : ", k);
k.remove(1);
print("After removng 1 : ",k);
print("Index of 5 in List l : ",l.index(5));
# Out:
# [4, 5, 8]
# [4, 5, 8, 9]
# count of 4 in List l is :  1
# Reverse of List l is :  [9, 8, 5, 4]
# Popped Element is :  4
# [9, 8, 5, 1, 2, 3]
# list in sorted order :  [1, 2, 3, 5, 8, 9]
# list k is cleared :  []
# List L is copied in K :  [1, 2, 3, 5, 8, 9]
# After removng 1 :  [2, 3, 5, 8, 9]
# Index of 5 in List l :  3

# %%
#Disctionary with functions
d={"Niru":"Kinjal","Nihal":"Appu"}
print(d);
print("Niru value: ",d.get("Niru"));
print("Items contend in D: ",d.items());
print("All values:",d.values());
print("D is cleared ",d.clear());
d={"Niru":"Ammu","Nihal":"Appu"};
print("Niru is popped", d.pop("Niru"));
# Out:
# {'Niru': 'Kinjal', 'Nihal': 'Appu'}
# Niru value:  Kinjal
# Items contend in D:  dict_items([('Niru', 'Kinjal'), ('Nihal', 'Appu')])
# All values: dict_values(['Kinjal', 'Appu'])
# D is cleared  None
# One element is popped Ammu

# %%
#Set with functions
s={"Niru",7,"Ammu",8}
print(s);
s.add("Love");
print("Add Love t set: ", s);
s.remove(7);
print("7 is removed: ", s);
a={};
a=s.copy();
print("S is copied in a: ",a);
print("When a is union with s: ",a.union(s));
s.discard(8);
print(s);
# Out:
# {8, 'Ammu', 'Niru', 7}
# Add Love t set:  {'Love', 8, 7, 'Ammu', 'Niru'}
# 7 is removed:  {'Love', 8, 'Ammu', 'Niru'}
# S is copied in a:  {8, 'Ammu', 'Niru', 'Love'}
# When a is union with s:  {'Love', 8, 'Ammu', 'Niru'}
# {'Love', 'Ammu', 'Niru'}
